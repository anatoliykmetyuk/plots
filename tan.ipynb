# %%
from plots import *
output_notebook()
plot, source = new_plot()
jupyter_two_colons()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a9bae184-d3b3-46b1-97d1-0f507146e943">Loading BokehJS ...</span>
#     </div>
# <style>
#   div#notebook-container.container {
#     /* This acts as a spacer between cells, that is outside the border */
#     margin: 2px 0px 2px 0px;
#     list-style: none;
#     padding: 0;
#     margin: 0;
#     -ms-box-orient: horizontal;
#     display: -webkit-box;
#     display: -moz-box;
#     display: -ms-flexbox;
#     display: -moz-flex;
#     display: -webkit-flex;
#     display: flex;
#     justify-content: space-around;
#     -webkit-flex-wrap: wrap;
#     flex-wrap: wrap;
#     -webkit-flex-direction: row;
#     flex-direction: row;
#   }
#   div.cell {
#   width:550px
#   }
# </style>

# %%
def sin_gen(amplitude, offset, phase, freq):
    def f(x): return amplitude * np.sin(freq*x + phase) + offset
    return f

# %%
show(plot, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="10ba6d7f-75fb-4e7e-805a-a5f63d90b4a7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("10ba6d7f-75fb-4e7e-805a-a5f63d90b4a7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f0037c85-cdb3-4f2f-8df5-fd5100443e29", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10ba6d7f-75fb-4e7e-805a-a5f63d90b4a7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10ba6d7f-75fb-4e7e-805a-a5f63d90b4a7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bdb42ad9-aedd-4b0b-9199-b4ea42ae57f3":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"63f795db-bf82-4d57-aecb-e8b5626fcd08","type":"CrosshairTool"},{"id":"b75a529b-1a94-4760-9116-41975099514c","type":"PanTool"},{"id":"93a81d8e-9d21-40e3-96be-6a5afdfaf349","type":"ResetTool"},{"id":"4d66cd64-ee2b-4a5e-a67b-fd65ad7326ca","type":"SaveTool"},{"id":"52579da9-531e-4699-bd41-16c3710c6fcd","type":"WheelZoomTool"}]},"id":"6940c9ec-d732-454f-97b3-e59500af5f15","type":"Toolbar"},{"attributes":{"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"},"ticker":{"id":"87a00ac9-768d-4169-86ed-0cd2ea56c5ec","type":"BasicTicker"}},"id":"a24210ca-4a17-4fef-84bc-889e4acca731","type":"Grid"},{"attributes":{"data_source":{"id":"faa8b31f-a3ad-4848-be8e-61717ea861f2","type":"ColumnDataSource"},"glyph":{"id":"f17cee72-e5b3-4a6d-9a4b-049118f09be6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6a0e6b24-c397-4374-9a87-8f2a61efe135","type":"Line"},"selection_glyph":null},"id":"a7791b32-3a1c-4ed5-a31f-d60ac1773044","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":12.566370614359172},"id":"3b4133ad-e037-4c3d-8cdc-3dbc40c5a1ad","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f17cee72-e5b3-4a6d-9a4b-049118f09be6","type":"Line"},{"attributes":{"formatter":{"id":"797bdf4b-e0dc-4538-98d6-dfb6149370e1","type":"BasicTickFormatter"},"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"},"ticker":{"id":"e213538e-20f9-46ac-9118-d61d53d7754e","type":"BasicTicker"}},"id":"f6805a76-fceb-4595-bfc6-e399e7371dba","type":"LinearAxis"},{"attributes":{"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"}},"id":"52579da9-531e-4699-bd41-16c3710c6fcd","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"}},"id":"93a81d8e-9d21-40e3-96be-6a5afdfaf349","type":"ResetTool"},{"attributes":{"formatter":{"id":"fdeca9aa-0674-4c25-97ac-91c7405f49d7","type":"BasicTickFormatter"},"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"},"ticker":{"id":"87a00ac9-768d-4169-86ed-0cd2ea56c5ec","type":"BasicTicker"}},"id":"92129477-c9ed-4c18-a6b3-590ca933cf65","type":"LinearAxis"},{"attributes":{},"id":"358d24a4-2878-4b68-8032-c0c3f7096bbd","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"0b100219-17ae-4ab4-bdaf-824952099297","subtype":"Figure","type":"Plot"},"ticker":{"id":"e213538e-20f9-46ac-9118-d61d53d7754e","type":"BasicTicker"}},"id":"794f7863-6419-4da5-9ae8-aaf9f748d0fd","type":"Grid"},{"attributes":{},"id":"e213538e-20f9-46ac-9118-d61d53d7754e","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Plot"},"id":"d83d121c-507f-4bd4-981e-384611d73b14","type":"Title"},{"attributes":{},"id":"797bdf4b-e0dc-4538-98d6-dfb6149370e1","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a0e6b24-c397-4374-9a87-8f2a61efe135","type":"Line"},{"attributes":{"below":[{"id":"92129477-c9ed-4c18-a6b3-590ca933cf65","type":"LinearAxis"}],"left":[{"id":"f6805a76-fceb-4595-bfc6-e399e7371dba","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"92129477-c9ed-4c18-a6b3-590ca933cf65","type":"LinearAxis"},{"id":"a24210ca-4a17-4fef-84bc-889e4acca731","type":"Grid"},{"id":"f6805a76-fceb-4595-bfc6-e399e7371dba","type":"LinearAxis"},{"id":"794f7863-6419-4da5-9ae8-aaf9f748d0fd","type":"Grid"},{"id":"a7791b32-3a1c-4ed5-a31f-d60ac1773044","type":"GlyphRenderer"}],"title":{"id":"d83d121c-507f-4bd4-981e-384611d73b14","type":"Title"},"tool_events":{"id":"358d24a4-2878-4b68-8032-c0c3f7096bbd","type":"ToolEvents"},"toolbar":{ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %%
interact(
    update_gen(sin_gen, source, 0, 4*np.pi, 200)
  , amplitude=(1, 2, 0.1)
  , offset=(0, 1)
  , phase=(0, 1)
  , freq=(1, 2))
